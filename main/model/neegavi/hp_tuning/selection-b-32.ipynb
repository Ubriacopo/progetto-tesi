# %%
# Configs:
c1 = {
    "lr": 3e-4,
    "batch_size": 32,
    "attn_layers": 6,
    "beta": 0.25
}

c2 = {
    "lr": 3e-4,
    "batch_size": 32,
    "attn_layers": 6,
    "beta": 0.5
}

# %%
c1_scores = [0.5938584208488464, 0.5842204093933105, 0.6054736375808716]
c2_scores = [0.5946041345596313, 0.6300684809684753, 0.5898647308349609]

# %%
import numpy as np

np.mean(c1_scores)
# Out:
# np.float64(0.5945174892743429)

# %%
np.mean(c2_scores)
# Out:
# np.float64(0.6048457821210226)

# %%
# Thus best winning config is c2
