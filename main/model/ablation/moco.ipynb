# %%
# Difference of 0.07 is quite huge.
# Training is more stable moco-less thus we opt to remove it.
# Model ckpt: /home/jacopo/PycharmProjects/progetto-tesi/main/model/script/outputs/ablation-moco-best/2026-03-24_00-32-18/checkpoints/epochepoch=38-stepstep=99567.ckpt

# %% [markdown]
# # Model Baseline

# %%
import numpy as np

baselines = np.array([0.6480, 0.6336, 0.7105])  # For Seeds: [1, 42, 150]

# Overall with MoCo training is pretty unstable

# %%
baseline_vals = np.array(baselines)
baseline_mean = baseline_vals.mean().item()
baseline_std = baseline_vals.std().item()
print("mean:", baseline_mean, " - std:", baseline_std)
# Out:
# mean: 0.6640333333333334  - std: 0.03337866916992879

# %% [markdown]
# MoCo-less values:

# %%
moco_less_mrr = np.array([0.7714, 0.7863])  # For seeds: [42,150]
(moco_less_mrr - baselines[1:]).mean()
# Out:
# np.float64(0.10679999999999995)

# %% [markdown]
# Around 3 times the std. MoCo is to remove.
