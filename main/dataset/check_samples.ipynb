# %%
from main.core_data.dataset import CachableDatasetDescriptor
from main.model.neegavi.train_utils import KdTrainDataModule

descriptors = [
    CachableDatasetDescriptor(**{
        "dataset_path": "/home/jacopo/dataset/EEGAVI/AMIGOS/combined-compressed/",
        "cache_path": None,
        "dataset_weight": 149
    }),
    CachableDatasetDescriptor(**{
        "dataset_path": "/home/jacopo/dataset/EEGAVI/MAHNOB/combined-compressed/",
        "cache_path": None,
        "dataset_weight": 30
    }),
    CachableDatasetDescriptor(**{
        "dataset_path": "/home/jacopo/dataset/EEGAVI/DEAP/combined-compressed/",
        "cache_path": None,
        "dataset_weight": 108
    }),
    CachableDatasetDescriptor(**{
        "dataset_path": "/home/jacopo/dataset/EEGAVI/EAV/combined-compressed/",
        "cache_path": None,
        "dataset_weight": 200
    })]

data = KdTrainDataModule(descriptors, 32, 1, ["eeg", "aud", "vid", "txt", "ecg"])

data.setup("train")
print(data.size("train"))
print(data.size("val"))
print(data.size("test"))
# Out:
# Dataset with CachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/AMIGOS/combined-compressed/', cache_path=None, dataset_weight=149) has a total of 587 train samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/AMIGOS/combined-compressed/', cache_path=None, dataset_weight=149) has a total of 110 validation samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/AMIGOS/combined-compressed/', cache_path=None, dataset_weight=149) has a total of 135 validation samples
#
# Dataset with CachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/MAHNOB/combined-compressed/', cache_path=None, dataset_weight=30) has a total of 25 train samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/MAHNOB/combined-compressed/', cache_path=None, dataset_weight=30) has a total of 2 validation samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/MAHNOB/combined-compressed/', cache_path=None, dataset_weight=30) has a total of 7 validation samples
#
# Dataset with CachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/DEAP/combined-compressed/', cache_path=None, dataset_weight=108) has a total of 321 train samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/DEAP/combined-compressed/', cache_path=None, dataset_weight=108) has a total of 69 validation samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/DEAP/combined-compressed/', cache_path=None, dataset_weight=108) has a total of 112 validation samples
#
# Dataset with CachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/EAV/combined-compressed/', cache_path=None, dataset_weight=200) has a total of 1620 train samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/EAV/combined-compressed/', cache_path=None, dataset_weight=200) has a total of 200 validation samples
# Dataset with fCachableDatasetDescriptor(dataset_path='/home/jacopo/dataset/EEGAVI/EAV/combined-compressed/', cache_path=None, dataset_weight=200) has a total of 303 validation samples
#
# 2553
# 381
# 557

# %%
# AMIGOS
# 587 + 110  + 135
# EAV
# 1620 + 200 + 303
# DEAP
# 321 + 69 + 112
# MAHNOB
# 25  + 2 + 7
