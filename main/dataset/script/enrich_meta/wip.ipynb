# %%
student_dataset_path = "/home/jacopo/PycharmProjects/progetto-tesi/data/EEGAVI/EAV/interleaved"

# %%
from pathlib import Path
import pandas as pd
import tensordict

a = pd.read_csv(Path(student_dataset_path) / "spec.csv")

for i in a.itertuples(index=False):
    td = tensordict.load(Path(student_dataset_path) / str(i.eid))
    print(td["meta"])
    break
# Out:
# TensorDict(
#     fields={
#         dataset_id: MemoryMappedTensor(shape=torch.Size([4]), device=cpu, dtype=torch.int64, is_shared=True),
#         interval: MemoryMappedTensor(shape=torch.Size([4, 2]), device=cpu, dtype=torch.float64, is_shared=True),
#         nei: MemoryMappedTensor(shape=torch.Size([4]), device=cpu, dtype=torch.int64, is_shared=True)},
#     batch_size=torch.Size([4]),
#     device=cpu,
#     is_shared=False)
